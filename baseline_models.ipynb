# %% [markdown]
# # Our Solution

# %% [markdown]
# * GIN pretrained only zinc 250k
# * Joint training on EGFR data
#     * Activity-aware contrastive
#     * IC50 regression

# %% [markdown]
# # Baseline Models

# %% [markdown]
# ## Traditional ML (ECFP fingerprints)
#
# * SVR
#
# * XGBoost

# %% [markdown]
# ### Smiles based (Regression only)
#
# * smiles transformer

# %% [markdown]
# ### Graph Based (Regression only)
#
# * GAT
#
# * GCN
#
# * GraphSAGE
#
# * GIN
#
# * D-MPNN

# %% [markdown]
# ## Backbone Study
#
# * GIN
#
# * GCN
#
# * GraphSAGE

# %% [markdown]
# ### Pretraining Study
#
# * Our Solution
#
# * GIN (without pretraining) + joint training
#
# * GraphMAE(GIN) + joint training
#
# * GraphCL(GIN) + joint training

# %% [markdown]
# # Ablation
#
# * our solution
#
# * GIN (without pretrain) + joint training
#
# * pretrained GIN (joint training -> only regression)
#
# * pretrained GIN (joint training -> sequential)

# %% [markdown]
# # Optional
#
# * EGFR Dataset Scaling  Curve:
#     * 1k, 5k, 10k, 50k, 100k, 250k
# * 3 run uncertainty
# * Every model trained under scaffold split
